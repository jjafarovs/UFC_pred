# %% [markdown]
# # UFC Edge — Exploration Scratch Space
#
# Scratch notebook for EDA against `db/ufc.db`. Nothing here is imported by `src/` -- treat it as disposable.

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('../db/ufc.db')
pd.read_sql('SELECT * FROM fights LIMIT 10', conn)
# Out:
#            fight_id          event_id  event_date       weight_class  \
# 0  c13dc0cccef263f7  31e1ea6fe6b682f8  2026-06-27        Lightweight
# 1  012c307c9d446c4d  31e1ea6fe6b682f8  2026-06-27       Middleweight
# 2  809814f03ff3140c  31e1ea6fe6b682f8  2026-06-27        Lightweight
# 3  81cde317c156723b  31e1ea6fe6b682f8  2026-06-27          Flyweight
# 4  d83294b031502177  31e1ea6fe6b682f8  2026-06-27       Middleweight
# 5  35985895d4ef321e  31e1ea6fe6b682f8  2026-06-27       Middleweight
# 6  6a35ff33b8597904  31e1ea6fe6b682f8  2026-06-27       Welterweight
# 7  48b1ee7ab45add4c  31e1ea6fe6b682f8  2026-06-27  Light Heavyweight
# 8  5e7f4ba1210f433d  31e1ea6fe6b682f8  2026-06-27       Middleweight
# 9  1a7119f3996b5635  31e1ea6fe6b682f8  2026-06-27      Featherweight
#
#    title_fight  scheduled_rounds      fighter_1_id      fighter_2_id  \
# 0            0                 5  c814b4c899793af6  2e7878927067fdca
# ...
